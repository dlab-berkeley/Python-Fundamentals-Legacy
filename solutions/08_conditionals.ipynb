# %% [markdown]
# ## Challenge 1: Boolean Errors
#
# The following cell gives error(s). Identify each error and how to fix it.
#
# What is the output of the cell?

# %%
number_of_trees = 14
number_of_shrubs = 8
has_flowers = TRUE #Needs to be Trrue
 
# needs double == ; 
print((number_of_trees > 14) and (number_of_trees = number_of_shrubs) or not (has_flowers))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ff3301dc979f> in <module>
#       1 number_of_trees = 14
#       2 number_of_shrubs = 8
# ----> 3 has_flowers = TRUE
#       4
#       5 # needs double ==
#
# NameError: name 'TRUE' is not defined

# %%
number_of_trees = 14
number_of_shrubs = 8
has_flowers = True #Needs to be Trrue
 
# needs double == ; 
print((number_of_trees > 14) and (number_of_trees == number_of_shrubs) or not (has_flowers))
# Out:
# False

# %% [markdown]
# ## Challenge 2: Conditionals Practice
#
# The `scores` list contains numeric grades that we'd like to assign letter grades to.
#
# Run the code. Does the result match your expectations? If not, why?
#
# Consider:
# 1. How many 'A' grades do you expect based on the input? How many are in the output?
# 2. Are there multiple outputs per score?
# 3. Are the scores assigned the correct letter grades?

# %%
scores = [80, 85, 99, 75, 70, 68]

for score in scores:
    if score >= 80:
        print(score, 'is a B.')
    elif score >= 90:
        print(score, 'is an A.')
    if score >= 70: #change this to elif
        print(score, 'is a C.')
    else:
        print(score, 'is a D.')
        
# The order matters. We want to start with the most strict condition first
# Then follow with progressively broader conditions
# Also, the numbers are being evaluated twice. 
# We can avoid this by changing the second if to elif
# Out:
# 80 is a B.
# 80 is a C.
# 85 is a B.
# 85 is a C.
# 99 is a B.
# 99 is a C.
# 75 is a C.
# 70 is a C.
# 68 is a D.

# %%
## solution
scores = [80, 85, 99, 75, 70, 68]

for score in scores:
    if score >= 90:
        print(score, 'is an A.')
    elif score >= 80:
        print(score, 'is a B.')
    elif score >= 70: #change this to elif
        print(score, 'is a C.')
    else:
        print(score, 'is a D.')
# Out:
# 80 is a B.
# 85 is a B.
# 99 is an A.
# 75 is a C.
# 70 is a C.
# 68 is a D.

# %% [markdown]
# ## Challenge 3: If statements and aggregation
#
# From the list below, let's create a new list that has 0 where the value was negative, and the number at indices where the value is positve.

# %%
original = [-1.5, 0.2, 0.4, 0.0, -1.3, 0.4]
result = []

for value in original:
    if value < 0:
        result.append(0)
    else:
        result.append(value)
print(result)
# Out:
# [0, 0.2, 0.4, 0.0, 0, 0.4]

# %%
presidents = [
    "George Washington",
    "John Adams",
    "Thomas Jefferson",
    "James Madison",
    "James Monroe",
    "John Quincy Adams",
    "Andrew Jackson",
    "Martin Van Buren",
    "William Henry Harrison",
    "John Tyler",
    "James K. Polk",
    "Zachary Taylor",
    "Millard Fillmore",
    "Franklin Pierce",
    "James Buchanan",
    "Abraham Lincoln",
    "Andrew Johnson",
    "Ulysses S. Grant",
    "Rutherford B. Hayes",
    "James A. Garfield",
    "Chester A. Arthur",
    "Grover Cleveland",
    "Benjamin Harrison",
    "Grover Cleveland",
    "William McKinley",
    "Theodore Roosevelt",
    "William Howard Taft",
    "Woodrow Wilson",
    "Warren G. Harding",
    "Calvin Coolidge",
    "Herbert Hoover",
    "Franklin D. Roosevelt",
    "Harry S. Truman",
    "Dwight D. Eisenhower",
    "John F. Kennedy",
    "Lyndon B. Johnson",
    "Richard Nixon",
    "Gerald Ford",
    "Jimmy Carter",
    "Ronald Reagan",
    "George H. W. Bush",
    "Bill Clinton",
    "George W. Bush",
    "Barack Obama",
    "Donald Trump",
    "Joe Biden"]

# %%
last_name_b = []
for p in presidents:
    if p.split(' ')[-1][0] == 'B':
        last_name_b.append(p)
print(last_name_b)
# Out:
# ['Martin Van Buren', 'James Buchanan', 'George H. W. Bush', 'George W. Bush', 'Joe Biden']

# %%
# BONUS: Another method is list comprehension
[p for p in presidents if p.split(' ')[-1][0] == 'B']
# Out:
# ['Martin Van Buren',
#  'James Buchanan',
#  'George H. W. Bush',
#  'George W. Bush',
#  'Joe Biden']
